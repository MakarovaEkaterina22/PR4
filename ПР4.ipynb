# %% [markdown]
# <a href="https://colab.research.google.com/github/MakarovaEkaterina22/PR4/blob/main/%D0%9F%D0%A04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Снимок экрана 2021-10-20 в 11.02.25.png](data:image/png;base64,...)

# %%
class Tovar:
  def __init__(self, n, p):
    self.name = n
    self.proizvod = p
  def manufacture(self, p):
    return
  def use(self):
    return
  def market(self):
    return
class Product(Tovar):
  def __init__(self, n, p, s):
    Tovar.__init__(self, n, p)
    self.srok = s
  def spoil(self,s):
    return
  def eat(self):
    return
  def __str__(self):
    return('Имя - {} \n Производитель - {} \n Срок годности - {} \n Используется в приготовлении первых и вторых блюд \n Испортиться через {}'.format(self.name, self.proizvod,self.srok,self.srok))
class Milk_product(Product):
  def __init__(self, n,p,s,f):
    Product.__init__(self,n,p,s)
    self.fatness = f
  def spoil(self,s):
    return
  def whip(self):
    return
  def __str__(self):
    return('Имя - {} \n Производитель - {} \n Срок годности - {} \n Скиснет через {} \n Взбивается до крепких пиков \n Жирность - {}'.format(self.name,self.proizvod,self.srok,self.srok,self.fatness))

class Toy(Tovar):
  def __init__(self, n, p, m):
    Tovar.__init__(self, n, p)
    self.material = m
  def can(self, known):
    return self.can
  def say (self,word):
    return self.say
  def __str__(self):
    return ('Имя - {} \n Производитель - {} \n Материал - {} \n {} \n {}'.format(self.name, self.proizvod, self.material,self.can(''),self.say('')))

p1=Product('Макароны', 'Makfa', '1 год')
print(p1)
m_p =Milk_product('Сливки', 'Простоквашино', '10 дней', '33%')
print(m_p)
toys = Toy('Базз Лайтер', 'Disney', 'пластмасса')
toys.say('Говорит: Бесконечность - не предел!')
toys.can('Умеет: бегать, летать,ослепительно улыбаться')
print(toys)
# Out:
# Имя - Макароны
#  Производитель - Makfa
#  Срок годности - 1 год
#  Используется в приготовлении первых и вторых блюд
#  Испортиться через 1 год
# Имя - Сливки
#  Производитель - Простоквашино
#  Срок годности - 10 дней
#  Скиснет через 10 дней
#  Взбивается до крепких пиков
#  Жирность - 33%
# Имя - Базз Лайтер
#  Производитель - Disney
#  Материал - пластмасса
#  <bound method Toy.can of <__main__.Toy object at 0x7ff5e3642f10>>
#  <bound method Toy.say of <__main__.Toy object at 0x7ff5e3642f10>>
